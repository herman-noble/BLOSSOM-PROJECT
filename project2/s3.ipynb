# %%
import pandas as pd
import boto3
import pyarrow as pa

region = "eu-west-1"
s3 = boto3.client('s3',region_name=region)
#location = {'LocationConstraint': region}
bucket = "blossom-data-engs"

s3.download_file(bucket,"free-7-million-company-dataset.zip",'data.zip')

# %%
df=pd.read_csv('data.zip', compression ='zip')
df
# Out:
#         Unnamed: 0                          name             domain  \
# 0          5872184                           ibm            ibm.com
# 1          4425416     tata consultancy services            tcs.com
# 2            21074                     accenture      accenture.com
# 3          2309813                       us army         goarmy.com
# 4          1558607                            ey             ey.com
# ...            ...                           ...                ...
# 204844     4165370  caron transportation systems  carontransport.ca
# 204845     4859186                  ramada hotel  canaltahotels.com
# 204846     5831392       phelan construction ltd      phelans.co.uk
# 204847     4029001                        cebbco         cebbco.com
# 204848     4603252    laboratorio médico polanco      lmpolanco.com
#
#        year founded                             industry size range  \
# 0              1911  information technology and services     10001+
# ...

# %%
df.head(2)
# Out:
#    Unnamed: 0                       name   domain year founded  \
# 0     5872184                        ibm  ibm.com         1911
# 1     4425416  tata consultancy services  tcs.com         1968
#
#                               industry size range  \
# 0  information technology and services     10001+
# 1  information technology and services     10001+
#
#                             locality        country  \
# 0  new york, new york, united states  united states
# 1         bombay, maharashtra, india          india
#
#                                      linkedin url current employee estimate  \
# 0                        linkedin.com/company/ibm                    274047
# 1  linkedin.com/company/tata-consultancy-services                    190771
#
#    total employee estimate  Unnamed: 11
# 0                   716906          NaN
# 1                   341369          NaN

# %%
df=df.dropna()
df.shape
# Out:
# (6, 12)

# %%
#table = pa.Table.from_pandas(df)
df.to_parquet('free-data-7-million-dataset.parquet')
df.to_json('free-data-7-million-dataset-json.gzip', compression='gzip')
