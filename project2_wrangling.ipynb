# %%
import pandas as pd


import numpy as np

df = pd.read_csv("C:\\Users\\HERMAN_NOBLE\\Desktop\\BLOSSOM\\assigngement1\\billboard.csv")
df
# Out:
#                  artiste                                  track genre  \
# 0        Destiny's Child               Independent Women Part I  Rock
# 1                Santana                           Maria, Maria  Rock
# 2          Savage Garden                     I Knew I Loved You  Rock
# 3                Madonna                                  Music  Rock
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ..                   ...                                    ...   ...
# 312     Ghostface Killah                       Cherchez LaGhost   R&B
# 313          Smith, Will                            Freakin' It   Rap
# 314        Zombie Nation                          Kernkraft 400  Rock
# 315       Eastsidaz, The                               Got Beef   Rap
# 316               Fragma                         Toca's Miracle   R&B
#
#     date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  x4th.week  \
# ...

# %%
df.shape
# Out:
# (317, 81)

# %%
df.columns
# Out:
# Index(['artiste', 'track', 'genre', 'date.entered', 'date.peaked', 'x1st.week',
#        'x2nd.week', 'x3rd.week', 'x4th.week', 'x5th.week', 'x6th.week',
#        'x7th.week', 'x8th.week', 'x9th.week', 'x10th.week', 'x11th.week',
#        'x12th.week', 'x13th.week', 'x14th.week', 'x15th.week', 'x16th.week',
#        'x17th.week', 'x18th.week', 'x19th.week', 'x20th.week', 'x21st.week',
#        'x22nd.week', 'x23rd.week', 'x24th.week', 'x25th.week', 'x26th.week',
#        'x27th.week', 'x28th.week', 'x29th.week', 'x30th.week', 'x31st.week',
#        'x32nd.week', 'x33rd.week', 'x34th.week', 'x35th.week', 'x36th.week',
#        'x37th.week', 'x38th.week', 'x39th.week', 'x40th.week', 'x41st.week',
#        'x42nd.week', 'x43rd.week', 'x44th.week', 'x45th.week', 'x46th.week',
#        'x47th.week', 'x48th.week', 'x49th.week', 'x50th.week', 'x51st.week',
#        'x52nd.week', 'x53rd.week', 'x54th.week', 'x55th.week', 'x56th.week',
# ...

# %%
df.dtypes
# Out:
# artiste          object
# track            object
# genre            object
# date.entered     object
# date.peaked      object
#                  ...
# x72nd.week      float64
# x73rd.week      float64
# x74th.week      float64
# x75th.week      float64
# x76th.week      float64
# Length: 81, dtype: object

# %%
df['date.entered'] = pd.to_datetime(df['date.entered'])

df.dtypes['date.entered']
# Out:
# dtype('<M8[ns]')

# %%
df['date.peaked'] = pd.to_datetime(df['date.peaked'])

df.dtypes
# Out:
# artiste                 object
# track                   object
# genre                   object
# date.entered    datetime64[ns]
# date.peaked     datetime64[ns]
#                      ...
# x72nd.week             float64
# x73rd.week             float64
# x74th.week             float64
# x75th.week             float64
# x76th.week             float64
# Length: 81, dtype: object

# %%
df.columns
# Out:
# Index(['artiste', 'track', 'genre', 'date.entered', 'date.peaked', 'x1st.week',
#        'x2nd.week', 'x3rd.week', 'x4th.week', 'x5th.week', 'x6th.week',
#        'x7th.week', 'x8th.week', 'x9th.week', 'x10th.week', 'x11th.week',
#        'x12th.week', 'x13th.week', 'x14th.week', 'x15th.week', 'x16th.week',
#        'x17th.week', 'x18th.week', 'x19th.week', 'x20th.week', 'x21st.week',
#        'x22nd.week', 'x23rd.week', 'x24th.week', 'x25th.week', 'x26th.week',
#        'x27th.week', 'x28th.week', 'x29th.week', 'x30th.week', 'x31st.week',
#        'x32nd.week', 'x33rd.week', 'x34th.week', 'x35th.week', 'x36th.week',
#        'x37th.week', 'x38th.week', 'x39th.week', 'x40th.week', 'x41st.week',
#        'x42nd.week', 'x43rd.week', 'x44th.week', 'x45th.week', 'x46th.week',
#        'x47th.week', 'x48th.week', 'x49th.week', 'x50th.week', 'x51st.week',
#        'x52nd.week', 'x53rd.week', 'x54th.week', 'x55th.week', 'x56th.week',
# ...

# %%
#applying melt to obtain the week and rank column

df_music = pd.melt(df, id_vars=['artiste','track','genre','date.entered', 'date.peaked'], value_name = 'rank', var_name='week')
               

df_music
# Out:
#                    artiste                                  track genre  \
# 0          Destiny's Child               Independent Women Part I  Rock
# 1                  Santana                           Maria, Maria  Rock
# 2            Savage Garden                     I Knew I Loved You  Rock
# 3                  Madonna                                  Music  Rock
# 4      Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ...                    ...                                    ...   ...
# 24087     Ghostface Killah                       Cherchez LaGhost   R&B
# 24088          Smith, Will                            Freakin' It   Rap
# 24089        Zombie Nation                          Kernkraft 400  Rock
# 24090       Eastsidaz, The                               Got Beef   Rap
# 24091               Fragma                         Toca's Miracle   R&B
#
#       date.entered date.peaked        week  rank
# 0       2000-09-23  2000-11-18   x1st.week  78.0
# ...

# %%
#checking for data types
df_music.dtypes
# Out:
# artiste          object
# track            object
# genre            object
# date.entered     object
# date.peaked      object
# week             object
# rank            float64
# dtype: object

# %%
#changing the datatype for date.entered and date.peaked

df_music['date.entered'] = pd.to_datetime(df_music['date.entered'])


df_music['date.peaked'] = pd.to_datetime(df_music['date.peaked'])


df_music.dtypes
# Out:
# artiste                 object
# track                   object
# genre                   object
# date.entered    datetime64[ns]
# date.peaked     datetime64[ns]
# week                     int32
# rank                   float64
# dtype: object

# %%
df_music['week'] = df_music['week'].apply(str)

# %%
df_music['week'] = df_music['week'].str.extract('(\d+)').astype(int)

df_music
# Out:
#                    artiste                                  track genre  \
# 0          Destiny's Child               Independent Women Part I  Rock
# 1                  Santana                           Maria, Maria  Rock
# 2            Savage Garden                     I Knew I Loved You  Rock
# 3                  Madonna                                  Music  Rock
# 4      Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ...                    ...                                    ...   ...
# 24087     Ghostface Killah                       Cherchez LaGhost   R&B
# 24088          Smith, Will                            Freakin' It   Rap
# 24089        Zombie Nation                          Kernkraft 400  Rock
# 24090       Eastsidaz, The                               Got Beef   Rap
# 24091               Fragma                         Toca's Miracle   R&B
#
#       date.entered date.peaked  week  rank
# 0       2000-09-23  2000-11-18     1  78.0
# ...

# %%
df_music['week'] = df_music['week'].apply(int)

# %%
df_music.dtypes
# Out:
# artiste                 object
# track                   object
# genre                   object
# date.entered    datetime64[ns]
# date.peaked     datetime64[ns]
# week                     int64
# rank                   float64
# dtype: object

# %%
#extracting numbers from the week column
df_music['week'] = df_music['week'].str.extract('(\d+)').astype(int)

df_music
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-c8f036c5f2e7> in <module>
#       1 #extracting numbers from the week column
# ----> 2 df_music['week'] = df_music['week'].str.extract('(\d+)').astype(int)
#       3 df_music
#
# c:\users\herman_noble\desktop\blossom\blossom_env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# c:\users\herman_noble\desktop\blossom\blossom_env\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\herman_noble\desktop\blossom\blossom_env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'week'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-8fa146c382e8> in <module>
# ...
