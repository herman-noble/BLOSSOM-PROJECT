# %%
import pandas as pd
pew = pd.read_csv('C:\\Users\\HERMAN_NOBLE\\Desktop\\BLOSSOM\\assigngement1\\pew2.csv')
pew
# Out:
#                   RReliggon  lessthanten  tentotwenty  twentytothirty  \
# 0                  Agnostic           27           34              60
# 1                   Atheist           12           27              37
# 2                  Buddhist           27           21              30
# 3                  Catholic          418          617             732
# 4         Dont know/refused           15           14              15
# 5         Evangelical Prot           575          869            1064
# 6                    Hindu             1            9               7
# 7  Historically Black Prot           228          244             236
# 8         Jehovahs Witness            20           27              24
# 9                   Jewish            19           19              25
#
#    thirtytoforty  fortytofifty  fiftytoseventyfive
# 0             81            76                 137
# 1             52            35                  70
# ...

# %%
pew.dtypes
# Out:
# RReliggon             object
# lessthanten            int64
# tentotwenty            int64
# twentytothirty         int64
# thirtytoforty          int64
# fortytofifty           int64
# fiftytoseventyfive     int64
# dtype: object

# %%
pew = pew.rename(columns = {'RReliggon':'religion'})

# %%
pew
# Out:
#                    religion  lessthanten  tentotwenty  twentytothirty  \
# 0                  Agnostic           27           34              60
# 1                   Atheist           12           27              37
# 2                  Buddhist           27           21              30
# 3                  Catholic          418          617             732
# 4         Dont know/refused           15           14              15
# 5         Evangelical Prot           575          869            1064
# 6                    Hindu             1            9               7
# 7  Historically Black Prot           228          244             236
# 8         Jehovahs Witness            20           27              24
# 9                   Jewish            19           19              25
#
#    thirtytoforty  fortytofifty  fiftytoseventyfive
# 0             81            76                 137
# 1             52            35                  70
# ...

# %%
pew.dtypes
# Out:
# religion              object
# lessthanten            int64
# tentotwenty            int64
# twentytothirty         int64
# thirtytoforty          int64
# fortytofifty           int64
# fiftytoseventyfive     int64
# dtype: object

# %%
pew['fiftytoseventyfive'] = pew['fiftytoseventyfive'].apply(str)

# %%
pew.dtypes
# Out:
# religion              object
# lessthanten           object
# tentotwenty           object
# twentytothirty        object
# thirtytoforty         object
# fortytofifty          object
# fiftytoseventyfive    object
# dtype: object

# %%
pew = pew.rename(columns = {})

# %%
pew_melt = pd.melt(pew, id_vars=['religion'], value_vars=['lessthanten', 'tentotwenty', 'twentytothirty', 'thirtytoforty', 'fortytofifty', 'fiftytoseventyfive'],value_name ='frequency', var_name ='income_range')

# %%
pew_melt
# Out:
#                     religion        income_range frequency
# 0                   Agnostic         lessthanten        27
# 1                    Atheist         lessthanten        12
# 2                   Buddhist         lessthanten        27
# 3                   Catholic         lessthanten       418
# 4          Dont know/refused         lessthanten        15
# 5          Evangelical Prot          lessthanten       575
# 6                     Hindu          lessthanten         1
# 7   Historically Black Prot          lessthanten       228
# 8          Jehovahs Witness          lessthanten        20
# 9                    Jewish          lessthanten        19
# 10                  Agnostic         tentotwenty        34
# 11                   Atheist         tentotwenty        27
# 12                  Buddhist         tentotwenty        21
# 13                  Catholic         tentotwenty       617
# 14         Dont know/refused         tentotwenty        14
# ...

# %%
pew_melt['frequency'] = pew_melt['frequency'].apply(int)

# %%
pew_melt.dtypes
# Out:
# religion        object
# income_range    object
# frequency        int64
# dtype: object
